# %% [markdown]
# # Week 11 Exercises
#
# _McKinney 7.2, 11.1_
#
# The general activity that we are doing in this week's exercise is to explore and try to understand a particular data set.  In this case, it is
#
# 1. Read in the data file and filter down to only looking at MO hospitals
# 2. Aggregate by Hospital: sum the Denominator, use min Start Date, use max End Date  (watch for rows with no Denominator value!)
# 3. Calculate the average per day across that entire span
# 4. Histogram
# 5. Rank and find the hospital with the most

# %% [markdown]
# ## STEP 1 - Read and Filter
#
# <img src="images/step1.png" alt="Read and Filter Output" style="width: 500px; float: right; margin-left: 20px; border: 1px solid">
#
# In the first step, read in the data file from the data directory `/data/complications_all.csv`.  It is a CSV file and Pandas should read it in just fine.  Explore the file so that you understand the columns and values.  At the end of this step, create a variable called `mo_hospitals` that contains a data frame from the `complications_all.csv` file, filtered down to only contain those hospitals from the state of Missouri (MO).
#
# A screenshot is included for reference.

# %%
import pandas as pd

# %%
data = pd.read_csv("complications_all.csv") 
data.head()
# Out:
#   Facility ID                     Facility Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name    Phone Number     Measure ID  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701  COMP_HIP_KNEE
# 1  DOTHAN    AL     36301     HOUSTON  (334) 793-8701    MORT_30_AMI
# 2  DOTHAN    AL     36301     HOUSTON  (334) 793-8701   MORT_30_CABG
# 3  DOTHAN    AL     36301     HOUSTON  (334) 793-8701   MORT_30_COPD
# 4  DOTHAN    AL     36301     HOUSTON  (334) 793-8701     MORT_30_HF
#
#                                         Measure Name  \
# 0  Rate of complications for hip/knee replacement...
# 1               Death rate for heart attack patients
# 2               Death rate for CABG surgery patients
# 3                       Death rate for COPD patients
# 4              Death rate for heart failure patients
#
#                   Compared to National Denominator Score Lower Estimate  \
# 0  No Different Than the National Rate         292   3.2            2.1
# 1  No Different Than the National Rate         688    13           11.0
# 2  No Different Than the National Rate         291   4.3            2.6
# 3  No Different Than the National Rate         411   8.8            6.7
# 4  No Different Than the National Rate         869  12.7           10.7
#
#   Higher Estimate  Footnote  Start Date    End Date
# 0             4.8       NaN  04/01/2015  03/31/2018
# 1            15.5       NaN  07/01/2015  06/30/2018
# 2             6.8       NaN  07/01/2015  06/30/2018
# 3            11.4       NaN  07/01/2015  06/30/2018
# 4            15.0       NaN  07/01/2015  06/30/2018

# %%
filter = data['State']=='MO'
filter.head()
mo_hospitals = data[filter]

# %%
mo_hospitals.head()
# Out:
#       Facility ID          Facility Name        Address    City State  \
# 45534      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45535      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45536      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45537      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45538      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
#
#        ZIP Code County Name    Phone Number     Measure ID  \
# 45534     64804      JASPER  (417) 781-2727  COMP_HIP_KNEE
# 45535     64804      JASPER  (417) 781-2727    MORT_30_AMI
# 45536     64804      JASPER  (417) 781-2727   MORT_30_CABG
# 45537     64804      JASPER  (417) 781-2727   MORT_30_COPD
# 45538     64804      JASPER  (417) 781-2727     MORT_30_HF
#
#                                             Measure Name  \
# 45534  Rate of complications for hip/knee replacement...
# 45535               Death rate for heart attack patients
# 45536               Death rate for CABG surgery patients
# 45537                       Death rate for COPD patients
# 45538              Death rate for heart failure patients
#
#                       Compared to National Denominator Score Lower Estimate  \
# 45534  No Different Than the National Rate          26   2.5            1.4
# 45535  No Different Than the National Rate         175  13.9           11.0
# 45536  No Different Than the National Rate          91   2.5            1.2
# 45537  No Different Than the National Rate         326   8.5            6.5
# 45538  No Different Than the National Rate         461  13.1           10.7
#
#       Higher Estimate  Footnote  Start Date    End Date
# 45534             4.2       NaN  04/01/2015  03/31/2018
# 45535            16.9       NaN  07/01/2015  06/30/2018
# 45536             5.1       NaN  07/01/2015  06/30/2018
# 45537            10.9       NaN  07/01/2015  06/30/2018
# 45538            15.9       NaN  07/01/2015  06/30/2018

# %%
# These assertions will help make sure that you're on the right track.
assert(mo_hospitals['State'].unique() == ['MO'])
assert(mo_hospitals.shape == (2133,18))

# %% [markdown]
# ## STEP 2 - Transform and Aggregate
#
# <img src="images/step2.png" alt="Transforma and Aggregate Output" style="width: 500px; float: right; margin-left: 20px; border: 1px solid">
#
# In the next step, we need to aggregate the results by hospital.  There are some key fields that we want to summarize, though:
# * We want to know the earliest date that each hospital was participating in any program
# * We want to know the latest date that each hospital stopped participating in any program
# * We want to know the total number of patients in the denominators of these programs
#
# Some things to note:
# * You will need to convert the `Start Date` and `End Date` to actual datetime fields
# * You will need to clean up and convert the `Denominator` field to just be numeric - the rule that you should use it to simply remove any records where the `Denominator` is `'Not Available'`
#
# The final result of this step should be a new data frame called `mo_summary` that contains one row for each hospital and contains the min start date, max end date, and total denominator.  Use the names `start_date`, `end_date`, and `number` for those columns in `mo_summary`.
#
# A screenshot is included for reference.

# %%
import datetime

start_date = pd.to_datetime(data.int[0:8], format='%Y%m%d')
end_date = pd.to_datetime(data.int[0:8], format='%Y%m%d')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-5215485dc57e> in <module>
#       1 import datetime
#       2
# ----> 3 start_date = pd.to_datetime(data.int[0:8], format='%Y%m%d')
#       4 end_date = pd.to_datetime(data.int[0:8], format='%Y%m%d')
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'int'

# %%
not_avail = mo_hospitals['Denominator'] == 'Not Available'
mo_hospitals[not_avail].shape
number = mo_hospitals[~not_avail]
number.shape
mo_summary = number.groupby(['Facility ID','Facility Name','Address']).min()
mo_summary.head()
# Out:
#                                                                                   City  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY              JOPLIN
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY             BOONVILLE
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR  SAINT CHARLES
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET   SAINT JOSEPH
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST             SEDALIA
#
#                                                                         State  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY         MO
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY           MO
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR    MO
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET    MO
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST         MO
#
#                                                                          ZIP Code  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY          64804
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY            65233
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR     63301
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET     64506
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST          65302
#
#                                                                          County Name  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY            JASPER
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY              COOPER
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR  ST. CHARLES
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET     BUCHANAN
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST            PETTIS
#
#                                                                            Phone Number  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY       (417) 781-2727
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY         (660) 882-4100
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR  (636) 947-5000
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET  (816) 271-6000
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST       (660) 826-8833
#
#                                                                             Measure ID  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY       COMP_HIP_KNEE
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY          MORT_30_COPD
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR  COMP_HIP_KNEE
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET  COMP_HIP_KNEE
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST       COMP_HIP_KNEE
#
#                                                                                                               Measure Name  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY       A wound that splits open after surgery on the ...
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY                      Broken hip from a fall after surgery
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR  A wound that splits open after surgery on the ...
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET  A wound that splits open after surgery on the ...
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST       A wound that splits open after surgery on the ...
#
#                                                                                         Compared to National  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY       No Different Than the National Rate
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY         No Different Than the National Rate
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR  No Different Than the National Rate
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET  No Different Than the National Rate
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST       No Different Than the National Rate
#
#                                                                         Denominator  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY             1335
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY                128
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR        1271
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET       10150
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST              189
#
#                                                                         Score  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY       0.12
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY         0.11
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR  0.10
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET  0.10
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST       0.12
#
#                                                                         Lower Estimate  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY                   0
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY                     0
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR              0
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET              0
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST                   0
#
#                                                                         Higher Estimate  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY                  0.2
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY                    0.2
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR            0.19
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET            0.19
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST                 0.21
#
#                                                                          Footnote  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY            NaN
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY              NaN
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR       NaN
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET       NaN
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST            NaN
#
#                                                                          Start Date  \
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY       04/01/2015
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY         07/01/2015
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR  04/01/2015
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET  04/01/2015
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST       04/01/2015
#
#                                                                            End Date
# Facility ID Facility Name                            Address
# 260001      MERCY HOSPITAL JOPLIN                    100 MERCY WAY       03/31/2018
# 260004      COOPER COUNTY COMMUNITY HOSPITAL         17651 B HWY         06/30/2018
# 260005      SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES 300 1ST CAPITOL DR  03/31/2018
# 260006      MOSAIC LIFE CARE AT ST JOSEPH            5325 FARAON STREET  03/31/2018
# 260009      BOTHWELL REGIONAL HEALTH CENTER          601 E 14TH ST       03/31/2018

# %%
mo_summary = pd.DataFrame()

# %%
assert(mo_summary['number'].sum() == 1766908)
assert(mo_summary['start_date'].min() == pd.Timestamp(2015,4,1))
assert(mo_summary['end_date'].max() == pd.Timestamp(2018,6,30))
assert(mo_summary.shape == (108,3))
assert(mo_summary.loc['BARNES JEWISH HOSPITAL'].number == 131313)
assert(mo_summary.loc['BOONE HOSPITAL CENTER'].number == 63099)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'number'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-113a3b1e83b4> in <module>
# ----> 1 assert(mo_summary['number'].sum() == 1766908)
#       2 assert(mo_summary['start_date'].min() == pd.Timestamp(2015,4,1))
#       3 assert(mo_summary['end_date'].max() == pd.Timestamp(2018,6,30))
#       4 assert(mo_summary.shape == (108,3))
#       5 assert(mo_summary.loc['BARNES JEWISH HOSPITAL'].number == 131313)
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'number'

# %% [markdown]
# ## STEP 3: Average Per Day
#
# <img src="images/step3.png" alt="Average per Day" style="width: 500px; margin-left: 20px; float: right; border: 1px solid">
#
#
# The next step, now that we have a start date, end date, and total patients for each day is to calculate how many patients on average per day this represents.  You will need to calculate the number of days between the start date and end date, and then the average as total patients divided by number of days.
#
# Your final output should still be the variable `mo_summary`, and it will need to have two additional columns: `days` and `per_day`.
#
# A screenshot is included for reference.

# %%
# Put your code below and make sure that you add new columns to `mo_summary` 
# to have the contents described in the instructions.

mo_summary['duration'] = (mo_summary['End Date'] - mo_summary['Start Date'])
total_patient = mo_summary['Denominator'].sum
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-d4581d9a5c16> in <module>
#       2 # to have the contents described in the instructions.
#       3
# ----> 4 mo_summary['duration'] = (mo_summary['End Date'] - mo_summary['Start Date'])
#       5 total_patient = mo_summary['Denominator'].sum
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#     498         lvalues = extract_array(left, extract_numpy=True)
#     499         rvalues = extract_array(right, extract_numpy=True)
# --> 500         result = arithmetic_op(lvalues, rvalues, op, str_rep)
#     501
#     502         return _construct_result(left, result, index=left.index, name=res_name)
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op, str_rep)
#     195     else:
#     196         with np.errstate(all="ignore"):
# --> 197             res_values = na_arithmetic_op(lvalues, rvalues, op, str_rep)
#     198
#     199     return res_values
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
# --> 151         result = masked_arith_op(left, right, op)
#     152
#     153     return missing.dispatch_fill_zeros(op, left, right, result)
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/ops/array_ops.py in masked_arith_op(x, y, op)
#      92         if mask.any():
#      93             with np.errstate(all="ignore"):
# ---> 94                 result[mask] = op(xrav[mask], yrav[mask])
#      95
#      96     else:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
assert(mo_summary['days'].sum() == 123718)
assert(mo_summary['per_day'].mean() == 13.841279932122697)
assert(mo_summary['per_day'].min() == 0.023744292237442923)
assert(mo_summary['days'].min() == 729)
assert(mo_summary['days'].max() == 1186)

# %% [markdown]
# ## STEP 4: Histogram
#
# <img src="images/step4.png" alt="Histogram" style="width: 300px; float: right; margin-left: 20px; border: 1px solid">
#
# For this step, I want you to plot a histogram to give yourself a better understanding of this new metric we've calculated: how many patients per day have a potential complication.  Looking at the shape and distribution of the data might give us some indication of the hospital volume and quality.  (Don't take this too seriously, though.  We're cutting some important corners.)
#
# A screenshot is included for reference.

# %%
# %matplotlib inline
# Use the built-in Pandas histogram plotting capability to plot a histogram of the `per_day` values.
import numpy as np
mo_summary['time'] = mo_summary.duration // np.timedelta64(1, 'Y')

mo_summary.time.hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-d7f293389d8c> in <module>
#       2 # Use the built-in Pandas histogram plotting capability to plot a histogram of the `per_day` values.
#       3 import numpy as np
# ----> 4 mo_summary['time'] = mo_summary.duration // np.timedelta64(1, 'Y')
#       5
#       6 mo_summary.time.hist()
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'duration'

# %% [markdown]
# ## STEP 5: Rank Order
#
# Now that we see what the distribution looks like, you can tell that most of the `per_day` values are below 20.  There are, however, some outliers up around 100!  Who are those?  Let's rank the data set by the `per_day` value in descending order, examine them, and produce a list of the "top 3" based on this criteria.  That is, who are the top three hospitals based on having the highest `per_day` values.
#
# At the end of this step, put those hospital names in a list called `top_hospitals` and that will be used for testing.  They should be in the order they appear `[#1, #2, #3]`.  That is, if the top hospitals were Mercy (99.3), BJC (97.2), and MoBap (90.1), then you would have `top_hospitals = ['Mercy','BJC','MoBap']`

# %%
import numpy as np

# %%
top_hospitals = ['BARNES JEWISH HOSPITAL', 'MERCY HOSPITAL SPRINGFIELD', 'COX MEDICAL CENTERS']

# %%
assert(type(top_hospitals) == list)
### BEGIN HIDDEN TESTS
assert(top_hospitals == ['BARNES JEWISH HOSPITAL', 'MERCY HOSPITAL SPRINGFIELD', 'COX MEDICAL CENTERS'])
### END HIDDEN TESTS
